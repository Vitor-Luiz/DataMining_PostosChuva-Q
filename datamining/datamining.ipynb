# %%
import pandas as pd
import openpyxl
import f_stats_fig as fsf
import os
#from datamining import f_stats_fig as fsf
# Out:
# Que pasa mano?

# %%
#Caminho do arquivo (No caso Excel)
caminho_arquivo = r'C:\Users\DELL\anaconda3\envs\datamining\project\data\serie_temporal.xlsx'

#Para salvar as figuras automaticamente criaremos uma variável caminho_salva
caminho_salva = r'C:\Users\DELL\anaconda3\envs\datamining\project\data\figuras_datamining'
if not os.path.exists(caminho_salva):
    os.makedirs(caminho_salva)

#Lê o dataframe em formato excel
#df = pd.read_excel(io=caminho_arquivo,sheet_name="Planilha1",header=0,usecols="A:Q",engine='openpyxl')

df = fsf.leitura_xls(caminho_arquivo, "Planilha1", "A:Q")

df.columns = df.columns.str.strip() #Retira strings vazias dos dados
print(df.dtypes)
print(df.describe)
df
# Out:
# Data    datetime64[ns]
# P1             float64
# P2             float64
# P3             float64
# P4             float64
# P5             float64
# P6             float64
# P7             float64
# P8             float64
# P9             float64
# P10            float64
# P11            float64
# P12            float64
# P13            float64
# P14            float64
# P15            float64
# P16              int64
# dtype: object
# <bound method NDFrame.describe of          Data     P1     P2     P3     P4     P5     P6     P7     P8     P9  \
# 0  2012-01-01  251.7  378.4  384.8  264.8  284.7  296.2  241.8  428.9  540.2
# 1  2012-02-01   15.9   45.1  120.7  102.2  121.7  101.8   90.4   21.3  171.5
# 2  2012-03-01   84.4  170.4  131.6  152.5   56.6  163.7  121.3  192.7   77.5
# 3  2012-04-01   45.3   31.9   79.3  110.7   73.3   86.5   61.7   63.0   87.2
# 4  2012-05-01  101.0  118.1   72.4  111.3   48.1   64.4   47.4  184.8  140.9
# ...

# %%
x = fsf.teste("celso")
x
# Out:
# True
